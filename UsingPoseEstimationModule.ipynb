# %%
# !pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (0.2)
# Requirement already satisfied: IPython in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from import-ipynb) (8.37.0)
# Requirement already satisfied: nbformat in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: colorama in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (0.4.6)
# Requirement already satisfied: decorator in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from IPython->import-ipynb) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.5)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from nbformat->import-ipynb) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from nbformat->import-ipynb) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from nbformat->import-ipynb) (5.9.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.5.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from stack_data->IPython->import-ipynb) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from stack_data->IPython->import-ipynb) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\hp probook\appdata\local\programs\python\python310\lib\site-packages (from stack_data->IPython->import-ipynb) (0.2.3)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip list
# Out:
# Package                   Version
# ------------------------- -----------
# absl-py                   2.3.1
# asttokens                 3.0.1
# attrs                     25.4.0
# cffi                      2.0.0
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.2
# cycler                    0.12.1
# debugpy                   1.8.19
# decorator                 5.2.1
# exceptiongroup            1.3.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# flatbuffers               25.12.19
# fonttools                 4.61.1
# import-ipynb              0.2
# ipykernel                 7.1.0
# ipython                   8.38.0
# jedi                      0.19.2
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter_client            8.7.0
# jupyter_core              5.9.1
# kiwisolver                1.4.9
# matplotlib                3.10.8
# matplotlib-inline         0.2.1
# mediapipe                 0.10.9
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# numpy                     2.2.6
# opencv-contrib-python     4.12.0.88
# opencv-python             4.12.0.88
# packaging                 25.0
# parso                     0.8.5
# pillow                    12.1.0
# pip                       21.2.3
# platformdirs              4.5.1
# prompt_toolkit            3.0.52
# protobuf                  3.20.3
# psutil                    7.2.1
# pure_eval                 0.2.3
# pycparser                 2.23
# Pygments                  2.19.2
# pyparsing                 3.3.1
# python-dateutil           2.9.0.post0
# pyzmq                     27.1.0
# referencing               0.37.0
# rpds-py                   0.30.0
# setuptools                57.4.0
# six                       1.17.0
# sounddevice               0.5.3
# stack-data                0.6.3
# tornado                   6.5.4
# traitlets                 5.14.3
# typing_extensions         4.15.0
# wcwidth                   0.2.14
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'E:\ComputerVision\PoseEstimation\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import time
import import_ipynb  
import PoseEstimationModule as pm
cap=cv2.VideoCapture("PoseVideos/pose1.mp4")
if not cap.isOpened():
    print("Error: Could not open video.")

previousTime=0
detector=pm.poseDetector()
while True:
    # img:It is in BGR
    success,img=cap.read()
    if not success:
        break
    img=detector.findPose(img)
    lmList=detector.findPosition(img,draw=False)
    if len(lmList)!=0:
        # print("Land mark list",lmList)
        # Tracking particular Landmark only
        #Change 14 ,any number from 0-32
        landmarkID=int(32)
        specifLandmark=lmList[landmarkID]
        print("Specif Land Mark",specifLandmark)
        x_Position_Of_Specif_Landmark=specifLandmark[1]
        y_Position_Of_Specif_Landmark=specifLandmark[2]
        # Drawing Specific Land Mark
        cv2.circle(img,(x_Position_Of_Specif_Landmark,y_Position_Of_Specif_Landmark),9,(0,255,0),cv2.FILLED)
    currentTime=time.time()
    if previousTime != 0:
        fps=1/(currentTime-previousTime)
        cv2.putText(img,str(int(fps)),(70,50),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),3)
    previousTime=currentTime
    cv2.imshow("Image",img)
    
    if cv2.waitKey(1) & 0xFF == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Specif Land Mark [32, 262, 330]
# Specif Land Mark [32, 262, 331]
# Specif Land Mark [32, 262, 331]
# Specif Land Mark [32, 262, 332]
# Specif Land Mark [32, 262, 333]
# Specif Land Mark [32, 262, 333]
# Specif Land Mark [32, 261, 334]
# Specif Land Mark [32, 261, 334]
# Specif Land Mark [32, 261, 335]
# Specif Land Mark [32, 260, 336]
# Specif Land Mark [32, 259, 336]
# Specif Land Mark [32, 258, 337]
# Specif Land Mark [32, 258, 337]
# Specif Land Mark [32, 257, 338]
# Specif Land Mark [32, 256, 339]
# Specif Land Mark [32, 255, 339]
# Specif Land Mark [32, 255, 340]
# Specif Land Mark [32, 255, 340]
# Specif Land Mark [32, 255, 341]
# Specif Land Mark [32, 255, 341]
# Specif Land Mark [32, 255, 342]
# Specif Land Mark [32, 255, 343]
# Specif Land Mark [32, 255, 344]
# Specif Land Mark [32, 255, 344]
# Specif Land Mark [32, 257, 344]
# Specif Land Mark [32, 259, 344]
# Specif Land Mark [32, 260, 344]
# Specif Land Mark [32, 261, 345]
# Specif Land Mark [32, 260, 345]
# Specif Land Mark [32, 256, 345]
# Specif Land Mark [32, 245, 346]
# Specif Land Mark [32, 227, 346]
# Specif Land Mark [32, 217, 346]
# Specif Land Mark [32, 215, 346]
# Specif Land Mark [32, 214, 347]
# Specif Land Mark [32, 213, 347]
# Specif Land Mark [32, 211, 348]
# Specif Land Mark [32, 211, 348]
# Specif Land Mark [32, 211, 348]
# Specif Land Mark [32, 210, 349]
